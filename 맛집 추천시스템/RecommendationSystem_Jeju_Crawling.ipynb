# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
import requests
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
maatjip_num=[] # 검색한 URL 정보를 담을 리스트

# %%
# 검색할 키워드
keyword = '조천읍 맛집' 

# 네이버 지도에서 위의 키워드로 검색
url = f'https://map.naver.com/v5/search/{keyword}/place/'

driver = webdriver.Chrome('/Users/ds/chromedriver-2')
driver.get(url)

# 크롤링 진행 시간을 2초로 설정
time.sleep(2)
    
# iframe 변경
driver.switch_to.frame('searchIframe')

for num in tqdm(range(1,7)): # 조천읍 맛집을 검색하면 6장의 페이지가 나오기 때문에 크롤링 범위를 6장으로 제한한다. 
    
    # END 키를 눌러서 페이지 제일 하단으로 이동
    driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
    if num == 1: # 첫번째 페이지에서는 다른 동작을 하지 않고 그대로 크롤링
        pass
    else: # 두번째 페이지 부터는 옆으로 넘어가는 버튼을 클릭하고 크롤링
        driver.find_element_by_xpath(f'//*[@id="app-root"]/div/div[2]/div[2]/a[7]').click()

    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)



    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(2)

    maatjip_list = soup.findAll('li', {'class':'_1EKsQ _12tNp'})

    for i in tqdm(range(len(maatjip_list))):
        driver.find_element_by_xpath(f'//*[@id="_pcmap_list_scroll_container"]/ul/li[{str(i+1)}]/div[1]/a').send_keys(Keys.ENTER)
        time.sleep(1)
    
        current_url = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지

        unique_code = re.findall(r"place/(\d+)", current_url)
        maatjip_num.append(unique_code[0])
        time.sleep(1)
    
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_7547/2277315601.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Input In [3], in <module>
#       4 # 네이버 지도에서 위의 키워드로 검색
#       5 url = f'https://map.naver.com/v5/search/{keyword}/place/'
# ----> 7 driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#       8 driver.get(url)
#      10 # 크롤링 진행 시간을 2초로 설정
#
# File /opt/homebrew/Cellar/jupyterlab/3.2.8/libexec/lib/python3.9/site-packages/selenium/webdriver/chrome/webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
# ...

# %%
maatjip_num
# Out:
# ['1308050128',
#  '1274479359',
#  '1626068590',
#  '1146885120',
#  '1541220979',
#  '36859834',
#  '1203369807',
#  '1989759621',
#  '70213029',
#  '1177301296',
#  '37264330',
#  '37765917',
#  '1069438409',
#  '1886393142',
#  '16886040',
#  '1310265573',
#  '13467718',
#  '1385678513',
#  '1339557107',
#  '1199185736',
#  '36388446',
#  '1238279882',
#  '1636101910',
#  '38289242',
#  '1876373893',
#  '16885890',
#  '1609519097',
#  '1570836131',
#  '19494321',
#  '35055861',
#  '32164641',
#  '1010866310',
#  '1205131570',
#  '37197957',
#  '1308050128',
#  '1214973590',
#  '525384203',
#  '1029487558',
#  '16885844',
#  '1780156244',
#  '35992593',
#  '1376015896',
#  '1389132207',
#  '1292775098',
#  '13016415',
#  '21608244',
#  '19878342',
#  '1419520717',
#  '11611243',
#  '83192724',
#  '1292775098',
#  '1876373893',
#  '1892541407',
#  '1691390948',
#  '37766370',
#  '1044419982',
#  '1335813166',
#  '1230534126',
#  '36269591',
#  '1554528371',
#  '16888580',
# ...

# %%
maatjip_num1=[]
# 검색할 키워드
keyword = '구좌읍 맛집' 

# 네이버 지도에서 위의 키워드로 검색
url = f'https://map.naver.com/v5/search/{keyword}/place/'

driver = webdriver.Chrome('/Users/ds/chromedriver-2')
driver.get(url)

# 크롤링 진행 시간을 2초로 설정
time.sleep(2)
    
# iframe 변경
driver.switch_to.frame('searchIframe')

for num in tqdm(range(1,7)): # 조천읍 맛집을 검색하면 6장의 페이지가 나오기 때문에 크롤링 범위를 6장으로 제한한다. 
    
    # END 키를 눌러서 페이지 제일 하단으로 이동
    driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
    if num == 1: # 첫번째 페이지에서는 다른 동작을 하지 않고 그대로 크롤링
        pass
    else: # 두번째 페이지 부터는 옆으로 넘어가는 버튼을 클릭하고 크롤링
        driver.find_element_by_xpath(f'//*[@id="app-root"]/div/div[2]/div[2]/a[7]').click()

    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)



    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(2)

    maatjip_list = soup.findAll('li', {'class':'_1EKsQ _12tNp'})

    for i in tqdm(range(len(maatjip_list))):
        driver.find_element_by_xpath(f'//*[@id="_pcmap_list_scroll_container"]/ul/li[{str(i+1)}]/div[1]/a').send_keys(Keys.ENTER)
        time.sleep(2)
    
        current_url = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지

        unique_code = re.findall(r"place/(\d+)", current_url)
        maatjip_num1.append(unique_code[0])
        time.sleep(2)
    
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1227596170.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#   0%|                                                     | 0/6 [00:00<?, ?it/s]/var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1227596170.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1227596170.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤
# ...

# %%
maatjip_num1
# Out:
# ['1873309343',
#  '34621576',
#  '38553022',
#  '16880858',
#  '1100615356',
#  '38411991',
#  '1992920098',
#  '36176385',
#  '36898347',
#  '34347933',
#  '31204698',
#  '37053406',
#  '317627449',
#  '36690197',
#  '505847520',
#  '1191014356',
#  '1664779171',
#  '37853863',
#  '17032617',
#  '1957502323',
#  '1803296766',
#  '147696491',
#  '1086466980',
#  '1451006243',
#  '37559361',
#  '1574419480',
#  '37542377',
#  '1073816301',
#  '1440332612',
#  '1559169598',
#  '1087017189',
#  '1281784128',
#  '1864925800',
#  '1019541842',
#  '1529112749',
#  '1414924101',
#  '1528955401',
#  '35575211',
#  '751218452',
#  '1757129086',
#  '16878029',
#  '78505031',
#  '58605666',
#  '35541310',
#  '1254885016',
#  '1592490151',
#  '844746055',
#  '19858215',
#  '12886879',
#  '1762025236',
#  '1873309343',
#  '71699464',
#  '34658467',
#  '1682352329',
#  '1006563695',
#  '1847740414',
#  '71441654',
#  '38484059',
#  '1382122382',
#  '1209627223',
#  '1061179999',
#  '1537884971',
# ...

# %%
maatjip_num2=[]
# 검색할 키워드
keyword = '성산읍 맛집' 

# 네이버 지도에서 위의 키워드로 검색
url = f'https://map.naver.com/v5/search/{keyword}/place/'

driver = webdriver.Chrome('/Users/ds/chromedriver-2')
driver.get(url)

# 크롤링 진행 시간을 2초로 설정
time.sleep(2)
    
# iframe 변경
driver.switch_to.frame('searchIframe')

for num in tqdm(range(1,7)): # 조천읍 맛집을 검색하면 6장의 페이지가 나오기 때문에 크롤링 범위를 6장으로 제한한다. 
    
    # END 키를 눌러서 페이지 제일 하단으로 이동
    driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
    if num == 1: # 첫번째 페이지에서는 다른 동작을 하지 않고 그대로 크롤링
        pass
    else: # 두번째 페이지 부터는 옆으로 넘어가는 버튼을 클릭하고 크롤링
        driver.find_element_by_xpath(f'//*[@id="app-root"]/div/div[2]/div[2]/a[7]').click()

    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)



    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(2)

    maatjip_list = soup.findAll('li', {'class':'_1EKsQ _12tNp'})

    for i in tqdm(range(len(maatjip_list))):
        driver.find_element_by_xpath(f'//*[@id="_pcmap_list_scroll_container"]/ul/li[{str(i+1)}]/div[1]/a').send_keys(Keys.ENTER)
        time.sleep(1)
    
        current_url = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지

        unique_code = re.findall(r"place/(\d+)", current_url)
        maatjip_num2.append(unique_code[0])
        time.sleep(1)
    
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/3300867815.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#   0%|                                                     | 0/6 [00:00<?, ?it/s]/var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/3300867815.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/3300867815.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤
# ...

# %%
maatjip_num3=[]
# 검색할 키워드
keyword = '표선면 맛집' 

# 네이버 지도에서 위의 키워드로 검색
url = f'https://map.naver.com/v5/search/{keyword}/place/'

driver = webdriver.Chrome('/Users/ds/chromedriver-2')
driver.get(url)

# 크롤링 진행 시간을 2초로 설정
time.sleep(2)
    
# iframe 변경
driver.switch_to.frame('searchIframe')

for num in tqdm(range(1,7)): # 조천읍 맛집을 검색하면 6장의 페이지가 나오기 때문에 크롤링 범위를 6장으로 제한한다. 
    
    # END 키를 눌러서 페이지 제일 하단으로 이동
    driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
    if num == 1: # 첫번째 페이지에서는 다른 동작을 하지 않고 그대로 크롤링
        pass
    else: # 두번째 페이지 부터는 옆으로 넘어가는 버튼을 클릭하고 크롤링
        driver.find_element_by_xpath(f'//*[@id="app-root"]/div/div[2]/div[2]/a[7]').click()

    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)



    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(2)

    maatjip_list = soup.findAll('li', {'class':'_1EKsQ _12tNp'})

    for i in tqdm(range(len(maatjip_list))):
        driver.find_element_by_xpath(f'//*[@id="_pcmap_list_scroll_container"]/ul/li[{str(i+1)}]/div[1]/a').send_keys(Keys.ENTER)
        time.sleep(1)
    
        current_url = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지

        unique_code = re.findall(r"place/(\d+)", current_url)
        maatjip_num3.append(unique_code[0])
        time.sleep(1)
    
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/2701240244.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#   0%|                                                     | 0/6 [00:00<?, ?it/s]/var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/2701240244.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/2701240244.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤
# ...

# %%
maatjip_num4=[]
# 검색할 키워드
keyword = '남원읍 맛집' 

# 네이버 지도에서 위의 키워드로 검색
url = f'https://map.naver.com/v5/search/{keyword}/place/'

driver = webdriver.Chrome('/Users/ds/chromedriver-2')
driver.get(url)

# 크롤링 진행 시간을 2초로 설정
time.sleep(2)
    
# iframe 변경
driver.switch_to.frame('searchIframe')

for num in tqdm(range(1,7)): # 조천읍 맛집을 검색하면 6장의 페이지가 나오기 때문에 크롤링 범위를 6장으로 제한한다. 
    
    # END 키를 눌러서 페이지 제일 하단으로 이동
    driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
    if num == 1: # 첫번째 페이지에서는 다른 동작을 하지 않고 그대로 크롤링
        pass
    else: # 두번째 페이지 부터는 옆으로 넘어가는 버튼을 클릭하고 크롤링
        driver.find_element_by_xpath(f'//*[@id="app-root"]/div/div[2]/div[2]/a[7]').click()

    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)
    driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤 
    time.sleep(1)



    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(2)

    maatjip_list = soup.findAll('li', {'class':'_1EKsQ _12tNp'})

    for i in tqdm(range(len(maatjip_list))):
        driver.find_element_by_xpath(f'//*[@id="_pcmap_list_scroll_container"]/ul/li[{str(i+1)}]/div[1]/a').send_keys(Keys.ENTER)
        time.sleep(1)
    
        current_url = driver.current_url # 검색이 성공된 플레이스에 대한 개별 페이지

        unique_code = re.findall(r"place/(\d+)", current_url)
        maatjip_num4.append(unique_code[0])
        time.sleep(1)
    
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1676595979.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#   0%|                                                     | 0/6 [00:00<?, ?it/s]/var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1676595979.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="_pcmap_list_scroll_container"]').click()
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2173/1676595979.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END) # 스크롤
# ...

# %%
maatjip_num4
# Out:
# ['16943092',
#  '1289898000',
#  '17069378',
#  '1241083032',
#  '1639542730',
#  '1747589122',
#  '1474440673',
#  '37534496',
#  '810995268',
#  '16947222',
#  '1289898000',
#  '1503806574',
#  '1516247337',
#  '1881920232',
#  '1076013975',
#  '1694312549',
#  '1107501886',
#  '1254564010',
#  '1969497561',
#  '35678728',
#  '1554821265',
#  '635657792',
#  '1254564010',
#  '1503806574',
#  '1344547583',
#  '1092896410',
#  '1058859367',
#  '13286289',
#  '32359127',
#  '1923461323',
#  '1383042284',
#  '1896845952',
#  '1775214043',
#  '1991440455',
#  '37812375',
#  '130649329',
#  '881739252',
#  '1578577127',
#  '31519899',
#  '37909515',
#  '1289898000',
#  '16943092',
#  '36016398',
#  '1605149893',
#  '21608177',
#  '1581736406',
#  '1036578905',
#  '1565908025',
#  '1275795861',
#  '1296261166',
#  '36796528',
#  '1716289221',
#  '1410123271',
#  '1938080866',
#  '17072404',
#  '1950243741',
#  '1163392518',
#  '34509501',
#  '36422482',
#  '1807015750',
#  '1041680634',
# ...

# %%
ex = pd.DataFrame(maatjip_num)

# %%
ex.nunique()
# Out:
# 0    277
# dtype: int64

# %%
# _camping_num앞에 지역이름 바꿔서 저장!!
ex.to_csv('maatjip_num.csv')

# %%
pd.DataFrame(maatjip_num).to_csv('maatjip_num.csv')
pd.DataFrame(maatjip_num1).to_csv('maatjip_num1.csv')
pd.DataFrame(maatjip_num2).to_csv('maatjip_num2.csv')
pd.DataFrame(maatjip_num3).to_csv('maatjip_num3.csv')
pd.DataFrame(maatjip_num4).to_csv('maatjip_num4.csv')

# %% [markdown]
# ## 고유번호 가져와서 맛집 유형, 이름, 주소, 평균별점 크롤링

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time
from bs4 import BeautifulSoup 
from tqdm import tqdm
import requests
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
maatjip_type  = []  # 맛집 유형 
maatjip_name  = []  # 맛집 이름
maatjip_addr  = []  # 맛집 주소
maatjip_score = []  # 맛집 평균별점
maatjip_phone = []  # 맛집 전화번호
maatjip_site  = []  # 맛집 사이트(site) 
maatjip_info1 = []  # 맛집 부가설명1
maatjip_info2 = []  # 맛집 부가설명2

# %%
maatjip_num = pd.read_csv('maatjip_num.csv')
maatjip_num1 = pd.read_csv('maatjip_num1.csv')
maatjip_num2 = pd.read_csv('maatjip_num2.csv')
maatjip_num3 = pd.read_csv('maatjip_num3.csv')
maatjip_num4 = pd.read_csv('maatjip_num4.csv')

# %%
maatjip_num = maatjip_num[['0']]

# %%
maatjip_num=maatjip_num['0'].tolist()

# %%
maatjip_num
# Out:
# [1308050128,
#  1274479359,
#  1626068590,
#  1146885120,
#  1541220979,
#  36859834,
#  1203369807,
#  1989759621,
#  70213029,
#  1177301296,
#  37264330,
#  37765917,
#  1069438409,
#  1886393142,
#  16886040,
#  1310265573,
#  13467718,
#  1385678513,
#  1339557107,
#  1199185736,
#  36388446,
#  1238279882,
#  1636101910,
#  38289242,
#  1876373893,
#  16885890,
#  1609519097,
#  1570836131,
#  19494321,
#  35055861,
#  32164641,
#  1010866310,
#  1205131570,
#  37197957,
#  1308050128,
#  1214973590,
#  525384203,
#  1029487558,
#  16885844,
#  1780156244,
#  35992593,
#  1376015896,
#  1389132207,
#  1292775098,
#  13016415,
#  21608244,
#  19878342,
#  1419520717,
#  11611243,
#  83192724,
#  1292775098,
#  1876373893,
#  1892541407,
#  1691390948,
#  37766370,
#  1044419982,
#  1335813166,
#  1230534126,
#  36269591,
#  1554528371,
#  16888580,
#  36812592,
#  1668139213,
#  37882839,
#  36513237,
#  1764464799,
#  1737919751,
#  1118872447,
#  1271203564,
#  1636101910,
# ...

# %%
driver = webdriver.Chrome('/Users/ds/chromedriver-2')

for i in tqdm(maatjip_num):
    new_url = f'https://pcmap.place.naver.com/accommodation/1308050128/home?'
    driver.get(new_url)

    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    time.sleep(1)

    name = soup.find('span',{'class':'_3XamX'})
    style = soup.find('span',{'class':'_3ocDE'})
    addr = soup.find('span',{'class':'_2yqUQ'})
    score = soup.find('span',{'class':'_1Y6hi _1A8_M'})
    
    try:
        ## 캠핑장 유형
        maatjip_type.append(style.text)

        ## 캠핑장 이름
        maatjip_name.append(name.text)

        ## 캠핑장 주소
        maatjip_addr.append(addr.text)

        ## 캠핑장 평균별점
        maatjip_score.append(score.em.text)
    
    except:
        maatjip_score.append('none')
    
    ## 전화번호
    try:     
        phone_num = soup.find('span',{'class':'_3ZA0S'})
        maatjip_phone.append(phone_num.text)        
    except:
        maatjip_phone.append('none')  

    ## 캠핑장 사이트(site) 
    try:
        site = soup.find('div',{'class':'_2SBb1'})
        maatjip_site.append(site.text)        
    except:
        maatjip_site.append('none')
        
    ## 부가설명
    info = soup.findAll('li',{'class':'_1M_Iz'})
    
    s = -1 # 부가설명1
    t = -1 # 부가설명2

   
        
 
        
driver.quit()
# Out:
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2718/1666766644.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver-2')
#   1%|▌                                          | 4/300 [00:11<14:02,  2.85s/it]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2718/1666766644.py in <module>
#       3 for i in tqdm(maatjip_num):
#       4     new_url = f'https://pcmap.place.naver.com/accommodation/1308050128/home?'
# ----> 5     driver.get(new_url)
#       6
#       7     html = driver.page_source
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# ...

# %%
len(maatjip_type)
len(maatjip_name)
len(maatjip_addr)
len(maatjip_score)
len(maatjip_phone)
len(maatjip_site)
len(maatjip_info1)
len(maatjip_info2)
# Out:
# 599
# 599
# 599
# 600
# 600
# 600
# 0
# 0

# %%
maatjip_dict = {'Num':maatjip_num, 'Type':maatjip_type[1:], 'Name':maatjip_name[1:], 'Address':maatjip_addr[1:], 'Score':maatjip_score[1:], 'Phone':maatjip_phone[1:]}

# %%
# 맛집 정보 크롤링 해올때 num, type 등이 맨 첫번째 맛집을 연속으로 두번 크롤링 해오는데 왜그러는지 물어보기

# %%
maatjip_dict
# Out:
# {'Num': [1308050128,
#   1274479359,
#   1626068590,
#   1146885120,
#   1541220979,
#   36859834,
#   1203369807,
#   1989759621,
#   70213029,
#   1177301296,
#   37264330,
#   37765917,
#   1069438409,
#   1886393142,
#   16886040,
#   1310265573,
#   13467718,
#   1385678513,
#   1339557107,
#   1199185736,
#   36388446,
#   1238279882,
#   1636101910,
#   38289242,
#   1876373893,
#   16885890,
#   1609519097,
#   1570836131,
#   19494321,
#   35055861,
#   32164641,
#   1010866310,
#   1205131570,
#   37197957,
#   1308050128,
#   1214973590,
#   525384203,
#   1029487558,
#   16885844,
#   1780156244,
#   35992593,
#   1376015896,
#   1389132207,
#   1292775098,
#   13016415,
#   21608244,
#   19878342,
#   1419520717,
#   11611243,
#   83192724,
#   1292775098,
#   1876373893,
#   1892541407,
#   1691390948,
#   37766370,
#   1044419982,
#   1335813166,
#   1230534126,
#   36269591,
#   1554528371,
#   16888580,
#   36812592,
#   1668139213,
#   37882839,
#   36513237,
# ...

# %%
maatjip_info_df = pd.DataFrame(maatjip_dict)
maatjip_info_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sy/lzv1b4r92bqb6hy15tk2qy5h0000gn/T/ipykernel_2718/414176826.py in <module>
# ----> 1 maatjip_info_df = pd.DataFrame(maatjip_dict)
#       2 maatjip_info_df
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# # _camping_df 앞에 해당 지역이름 넣어서 돌리기!!!!

# %%
camp_info_df.to_csv('jeju_camping_info_df.csv')

# %%
camp_info_df = pd.read_csv('jeju_camping_info_df.csv')

# %%
camp_info_df
# Out:
#    Unnamed: 0         Num  Type            Name                 Address Score  \
# 0           0    37197957    라면      문개항아리 조천본점  제주 제주시 조천읍 조함해안로 217-1  4.78
# 1           1  1585586242  정육식당  대풍미락 정육식당 함덕본점    제주 제주시 조천읍 조함해안로 450  4.57
# 2           2  1626068590     차             연화차       제주 제주시 조천읍 선교로 46  4.97
# 3           3  1541220979    한식              회춘      제주 제주시 조천읍 신북로 489  none
#
#             Phone                                  URL  \
# 0  0507-1389-4775                                 none
# 1    064-784-8102                                 none
# 2  0507-1377-9974     http://instagram.com/yeonhwa.tea
# 3  0507-1336-0853  http://instagram.com/rejuvenate0853
#
#                                       info1  \
# 0  주차, 예약, 무선 인터넷, 남/녀 화장실 구분, 국민지원금, 국민지원금
# 1                         단체석, 국민지원금, 국민지원금
# 2       단체석, 주차, 포장, 예약, 무선 인터넷, 남/녀 화장실 구분
# 3         단체석, 주차, 남/녀 화장실 구분, 국민지원금, 국민지원금
#
#                                                info2
# ...

# %%
camp_info_df=camp_info_df[['Num','Type', 'Name', 'Address', 'Phone', 'Score','URL','info1','info2']]

# %%
jeju_camp_info=camp_info_df

# %%
jeju_camp_info.index = range(0,len(jeju_camp_info))

# %%
jeju_camp_info
# Out:
#           Num  Type            Name                 Address           Phone  \
# 0    37197957    라면      문개항아리 조천본점  제주 제주시 조천읍 조함해안로 217-1  0507-1389-4775
# 1  1585586242  정육식당  대풍미락 정육식당 함덕본점    제주 제주시 조천읍 조함해안로 450    064-784-8102
# 2  1626068590     차             연화차       제주 제주시 조천읍 선교로 46  0507-1377-9974
# 3  1541220979    한식              회춘      제주 제주시 조천읍 신북로 489  0507-1336-0853
#
#   Score                                  URL  \
# 0  4.78                                 none
# 1  4.57                                 none
# 2  4.97     http://instagram.com/yeonhwa.tea
# 3  none  http://instagram.com/rejuvenate0853
#
#                                       info1  \
# 0  주차, 예약, 무선 인터넷, 남/녀 화장실 구분, 국민지원금, 국민지원금
# 1                         단체석, 국민지원금, 국민지원금
# 2       단체석, 주차, 포장, 예약, 무선 인터넷, 남/녀 화장실 구분
# 3         단체석, 주차, 남/녀 화장실 구분, 국민지원금, 국민지원금
#
#                                                info2
# 0  문어 해루질 달인으로 kbs, mbc 등에 수차례 방송 되었던 주인장이 운영하는 제...
# ...

# %%
jeju_camp_info['Num'] = jeju_camp_info['Num'].astype('int')
# Out:
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/3243356868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jeju_camp_info['Num'] = jeju_camp_info['Num'].astype('int')

# %%
jeju_camp_info.to_csv('jeju_camp_info.csv')

# %% [markdown]
# ## 고유번호를 이용해 리뷰 페이지로 넘어가서 필요한 데이터 크롤링

# %%
camping_name_list = []
user_id_list      = []
camping_type_list = []
rating_list       = []
avg_rating_list   = []
date_list         = []
review_list       = []
count_list        = []

error             = [] # 에러 내용

# %%
driver = webdriver.Chrome('/Users/ds/chromedriver 2')

for i in range(len(jeju_camp_info)):
    
    review_url = 'https://pcmap.place.naver.com/accommodation/{}/review/visitor?'.format(jeju_camp_info['Num'][i])
#     print(review_url)
    try:
        print('======================================================')
        print(str(i+1)+'번째 캠핑장')

        # 캠핑장 리뷰 개별 url 접속
        driver.get(review_url)
        time.sleep(2) 
         
        while True:
            try:
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(3)
                # 더보기 버튼 클릭
                driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[4]/div[2]/a').click()
                time.sleep(3)
                # END 키를 눌러서 페이지 제일 하단으로 이동
                driver.find_element_by_tag_name('body').send_keys(Keys.END)
                time.sleep(1)

            except NoSuchElementException:
                print('-더보기 버튼 모두 클릭 완료-')
                break
                
        # 파싱
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        time.sleep(1)

        # 캠핑장 구분
        camping_site_name = jeju_camp_info['Name'][i]
        print('사업장명 : '+ camping_site_name)

        try:
            all_review = soup.find_all('div', attrs = {'class':'_1Z_GL'})
            review_num = len(all_review) # 특정 캠핑의 리뷰 총 개수
            print('리뷰 총 개수 : '+ str(review_num))

            print('----------------------------------------------')

            for review in range(review_num):
                
                ## 캠핑장 이름
                camping_name_list.append(camping_site_name)
                print(camping_site_name)

                ## user ID
                user = soup.find_all('div',{'class':'hbo4A'})
                print('{}번째 user:'.format(review+1),user[review].text)
                user_id_list.append(user[review].text)
                
                ## rating(사용자가 이 캠핑장에 준 별점)
                rating = all_review[review].find('span', attrs = {'class':'_2tObC'}).text
                print('rating = '+rating)
                rating_list.append(rating)

                ## 사용자의 평균 별점
                avg_rating = soup.find_all('div',{'class':'ql4ZC'})
                print('avg_rating ='+avg_rating[review].text)
                avg_rating_list.append(avg_rating[review].text)

                # 주의!!! 사진 리뷰 유무에 따라 날짜 파싱코드 다름
                # ('span', attrs = {'class':'_3WqoL'})
                # 사진 없는 경우 : 총 6개 중 4번째
                # 사진 있는 경우 : 총 5개 중 3번째

                ## date
                # 사진 리뷰 없음
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[2].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    date = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                else:
                    date = ""
                print('date = '+date)
                date_list.append(date)
                
                ## count 방문횟수
                if len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 5:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[3].text
                elif len(all_review[review].find_all('span', attrs = {'class':'_3WqoL'})) == 6:
                    count = all_review[review].find_all('span', attrs = {'class':'_3WqoL'})[4].text
                else:
                    count = ""
                print('방문횟수 = '+count)
                count_list.append(count)                

                ## review 내용
                try: 
                    review_content = all_review[review].find('span', attrs = {'class':'WoYOw'}).text
                except: # 리뷰가 없다면
                    review_content = ""
                print('리뷰 내용 : '+review_content)
                review_list.append(review_content)                    
                    
                print('\n\n')
                
        except Exception as total_review_err:
            none_review = "네이버 리뷰 0개"
            print(none_review)   

    
    except Exception as err:
        print(err)
        error_list = '{}행 에러 : {}'.format(i,err)
        error.append(error_list)
        rating_list.append(' ')
        avg_rating_list.append(' ')
        review_list.append(' ')

driver.quit()
# Out:
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/4079195133.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/ds/chromedriver 2')
# ...
# 1번째 캠핑장
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/4079195133.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_tag_name('body').send_keys(Keys.END)
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/4079195133.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="app-root"]/div/div/div[2]/div[5]/div[4]/div[4]/div[2]/a').click()
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/4079195133.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
review_data = {'Date':date_list, 'Name':camping_name_list, 'User_ID':user_id_list, 'Rating':rating_list, 'Avg_rating':avg_rating_list, 'Review':review_list}
review_df = pd.DataFrame(review_data)
review_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zz/lwjzp_r130b4y7w9qcwwkfhr0000gn/T/ipykernel_84032/2233140190.py in <module>
#       1 review_data = {'Date':date_list, 'Name':camping_name_list, 'User_ID':user_id_list, 'Rating':rating_list, 'Avg_rating':avg_rating_list, 'Review':review_list}
# ----> 2 review_df = pd.DataFrame(review_data)
#       3 review_df
#
# /opt/homebrew/Cellar/jupyterlab/3.2.4/libexec/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
review = []
avg_ratings = []
for i in review_df['Avg_rating'].tolist():
    a = re.findall('\d+[.]?\d*', i)
    try:
        review.append(a[0])
        avg_ratings.append(a[-1])    
    except:
        review.append('none')
        avg_ratings.append('none')

# %%
review_df['total_review']=review
review_df['user_avg_ratings']=avg_ratings

# %%
del review_df['Avg_rating']

# %%
review_df
# Out:
#            Date       Name    User_ID Rating  \
# 0    2021.10.17  제주플래티늄카라반      bccrr      5
# 1    2021.10.16  제주플래티늄카라반  barun3781      5
# 2    2021.10.14  제주플래티늄카라반       Dean      5
# 3    2021.10.14  제주플래티늄카라반   kohj2552      5
# 4    2021.10.12  제주플래티늄카라반       Isle      5
# ..          ...        ...        ...    ...
# 920  2021.10.04  협재해수욕장야영장       눈나무숲      5
# 921  2021.08.15  협재해수욕장야영장        가시리      5
# 922  2020.10.03  마레보리조트카라반     kimnew      5
# 923  2020.09.10  마레보리조트카라반       삐요삐요      4
# 924  2019.08.05      원앙캠핑장         사내      2
#
#                                                 Review total_review  \
# 0                            사장님도 친절하셨고 시설도 생각보다 넓었습니다            5
# 1    놀러가는날 날씨가 안좋아 사진을 못찍었지만 일단 사장님들 너무 친절하시고 날좋은날 ...            2
# 2             경치가 정말 아름다웠어요. 일몰 보면서 즐기는 바베큐 파티도 최고였어요.            5
# 3                             돈이 아깝지  않았어요 값어치한다고 느꼈어요           13
# 4                                            친절하고좋았씁니다            7
# ...

# %%
review_final = review_df[['Date','Name','User_ID','total_review','user_avg_ratings','Rating','Review']]
review_final
# Out:
#            Date       Name    User_ID total_review user_avg_ratings Rating  \
# 0    2021.10.17  제주플래티늄카라반      bccrr            5                5      5
# 1    2021.10.16  제주플래티늄카라반  barun3781            2              4.5      5
# 2    2021.10.14  제주플래티늄카라반       Dean            5                5      5
# 3    2021.10.14  제주플래티늄카라반   kohj2552           13              4.7      5
# 4    2021.10.12  제주플래티늄카라반       Isle            7                5      5
# ..          ...        ...        ...          ...              ...    ...
# 920  2021.10.04  협재해수욕장야영장       눈나무숲          897              4.8      5
# 921  2021.08.15  협재해수욕장야영장        가시리          111                4      5
# 922  2020.10.03  마레보리조트카라반     kimnew          709              4.7      5
# 923  2020.09.10  마레보리조트카라반       삐요삐요          110              4.1      4
# 924  2019.08.05      원앙캠핑장         사내          545              3.4      2
#
#                                                 Review
# ...

# %%
review_final.to_csv('jeju_camping_review.csv')
